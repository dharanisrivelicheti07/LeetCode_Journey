# %% [markdown]
# ### 15. 3Sum
# #### ![image.png](attachment:image.png)

# %% [markdown]
# ### Procedure
# ##### First, you sort the array so that the numbers are in increasing order. Then, you fix one number nums[i] and try to find two other numbers whose sum is -nums[i]. For those two numbers, you use two pointers: left starts just after i, and right starts at the end of the array. If the total sum is 0, you found a valid triplet. If the sum is less than 0, you move left forward to increase the sum. If the sum is greater than 0, you move right backward to decrease the sum. You repeat this for every possible i.

# %% [markdown]
# ### Java Solution
# ```java
# class Solution {
#     public List<List<Integer>> threeSum(int[] nums) {
#         if(nums == null || nums.length < 3) return new ArrayList<>();
#         Arrays.sort(nums);
#         Set<List<Integer>> result = new HashSet<>();
#         for(int i=0;i<nums.length-2;i++){
#             int left = i+1;
#             int right = nums.length-1;
#             while(left<right){
#                 int sum = nums[i]+nums[left]+nums[right];
#                 if(sum == 0){
#                     result.add(Arrays.asList(nums[i],nums[left],nums[right]));
#                     left++;
#                     right--;
#                 }
#                 else if(sum<0){
#                     left++;
#                 }
#                 else{
#                     right--;
#                 }
#             }
#
#         }
#         return new ArrayList<>(result);
#     }
# }
# ```

# %% [markdown]
# ### Cpp Solution
# ```cpp
# class Solution {
# public:
#     vector<vector<int>> threeSum(vector<int>& nums) {
#         vector<vector<int>> result;
#
#         sort(nums.begin(), nums.end());
#
#         for (int i = 0; i < nums.size() - 2; i++) {
#
#             int left = i + 1;
#             int right = nums.size() - 1;
#
#             while (left < right) {
#
#                 int sum = nums[i] + nums[left] + nums[right];
#
#                 if (sum == 0) {
#                     result.push_back({nums[i], nums[left], nums[right]});
#                     left++;
#                     right--;
#                 }
#                 else if (sum < 0) {
#                     left++;
#                 }
#                 else {
#                     right--;
#                 }
#             }
#         }
#
#         return result;
#     }
# };
# ```

# %% [markdown]
# ### Python Solution

# %%
class Solution:
    def threeSum(self, nums):
        result = []

        nums.sort()

        for i in range(len(nums) - 2):

            left = i + 1
            right = len(nums) - 1

            while left < right:

                total = nums[i] + nums[left] + nums[right]

                if total == 0:
                    result.append([nums[i], nums[left], nums[right]])
                    left += 1
                    right -= 1

                elif total < 0:
                    left += 1

                else:
                    right -= 1

        return result
