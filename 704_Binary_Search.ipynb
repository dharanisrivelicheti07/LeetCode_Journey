# %% [markdown]
# ### 704. Binary Search
# #### Given an array of integers nums which is sorted in ascending order, and an integer target, write a function to search target in nums. If target exists, then return its index. Otherwise, return -1.
# #### You must write an algorithm with O(log n) runtime complexity.
# #### Example: Input: nums = [-1,0,3,5,9,12], target = 9
# #### Output: 4

# %% [markdown]
# ### Description
# #### A binary search is an efficient "divide and conquer" algorithm that finds the position of a target value within a sorted array by repeatedly dividing the search space in half.
# #### Mathematically expressed as $O(\log n)$ time complexity, it takes a maximum of just 20 guesses to find an item in a list of 1 million elements.
# #### ![image.png](attachment:image.png)

# %% [markdown]
# ### Java Solution(Iterative)
# ```java
# public class BinarySearch {
#
#     public static int search(int[] arr, int target) {
#         // Define the initial search boundaries
#         int low = 0;
#         int high = arr.length - 1;
#
#         while (low <= high) {
#             // Use this instead of (low + high) / 2 to prevent integer overflow
#             int mid = low + (high - low) / 2;
#
#             if (arr[mid] == target) {
#                 return mid; // Target found, return its index
#             }
#
#             if (arr[mid] < target) {
#                 low = mid + 1; // Target is larger, discard the left half
#             } else {
#                 high = mid - 1; // Target is smaller, discard the right half
#             }
#         }
#
#         return -1; // Target not found in the array
#     }
# }
# ```

# %% [markdown]
# ### Java Solution(Recursive)
# ```java
# public class RecursiveBinarySearch {
#
#     // 1. The public wrapper method (Clean API for the user)
#     public static int search(int[] arr, int target) {
#         return searchRecursive(arr, target, 0, arr.length - 1);
#     }
#
#     // 2. The actual recursive method (Private helper)
#     private static int searchRecursive(int[] arr, int target, int low, int high) {
#
#         // Base case 1: Search space is exhausted (target not found)
#         if (low > high) {
#             return -1;
#         }
#
#         // Calculate mid to prevent integer overflow
#         int mid = low + (high - low) / 2;
#
#         // Base case 2: Target found
#         if (arr[mid] == target) {
#             return mid;
#         }
#
#         // Recursive step: Target is larger, search the right half
#         if (arr[mid] < target) {
#             return searchRecursive(arr, target, mid + 1, high);
#         }
#
#         // Recursive step: Target is smaller, search the left half
#         return searchRecursive(arr, target, low, mid - 1);
#     }
# }
# ```

# %% [markdown]
# ### Cpp solution
# ```cpp
# class Solution {
# public:
#     int search(vector<int>& nums, int target) {
#         int left = 0;
#         int right = nums.size() - 1;
#
#         while (left <= right) {
#             // Safe way to find mid without integer overflow
#             int mid = left + (right - left) / 2;
#
#             if (nums[mid] == target) {
#                 return mid;
#             } else if (nums[mid] < target) {
#                 left = mid + 1;  // Discard the left half
#             } else {
#                 right = mid - 1; // Discard the right half
#             }
#         }
#
#         return -1; // Target not found
#     }
# };
# ```

# %% [markdown]
# ### Python Solution

# %%
class Solution:
    def search(self, nums: List[int], target: int) -> int:
        left, right = 0, len(nums) - 1
        
        while left <= right:
            # // is integer division in Python 3
            mid = left + (right - left) // 2 
            
            if nums[mid] == target:
                return mid
            elif nums[mid] < target:
                left = mid + 1  # Discard the left half
            else:
                right = mid - 1 # Discard the right half
                
        return -1 # Target not found
