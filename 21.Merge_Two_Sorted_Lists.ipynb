# %% [markdown]
# ### 21. Merge Two Sorted Lists
# #### You are given the heads of two sorted linked lists list1 and list2.
# #### Merge the two lists into one sorted list. The list should be made by splicing together the nodes of the first two lists.
# #### Return the head of the merged linked list.
# #### Example: Input: list1 = [1,2,4], list2 = [1,3,4],Output: [1,1,2,3,4,4]

# %% [markdown]
# ### Java Solution
# ```java
# class Solution {
#     public ListNode mergeTwoLists(ListNode list1, ListNode list2) {
#         ListNode dummy = new ListNode(0);
#         ListNode current = dummy;
#         while(list1!=null && list2!=null){
#             if(list1.val<=list2.val){
#                 current.next = list1;
#                 list1 = list1.next;
#             }
#             else{
#                 current.next = list2;
#                 list2 = list2.next;
#             }
#             current = current.next;
#         }
#
#         if(list1!=null){
#             current.next = list1;
#         }
#         else{
#             current.next = list2;
#         }
#         return dummy.next;
#    }
# }
# ```

# %% [markdown]
# ### Cpp Solution
# ```cpp
# class Solution {
# public:
#     ListNode* mergeTwoLists(ListNode* list1, ListNode* list2) {
#         // Dummy node to simplify edge cases
#         ListNode dummy(0);
#         ListNode* current = &dummy;
#
#         // Traverse both lists until one is exhausted
#         while (list1 != nullptr && list2 != nullptr) {
#             if (list1->val <= list2->val) {
#                 current->next = list1;
#                 list1 = list1->next;
#             } else {
#                 current->next = list2;
#                 list2 = list2->next;
#             }
#             current = current->next;
#         }
#
#         // At least one list is empty, attach the remaining elements
#         if (list1 != nullptr) {
#             current->next = list1;
#         } else {
#             current->next = list2;
#         }
#
#         // Return the actual head of the merged list
#         return dummy.next;
#     }
# };
# ```

# %% [markdown]
# ### Python Solution

# %%
class Solution:
    def mergeTwoLists(self, list1: Optional[ListNode], list2: Optional[ListNode]) -> Optional[ListNode]:
        # Dummy node to serve as the starting point
        dummy = ListNode()
        current = dummy
        
        # Traverse both lists until one is exhausted
        while list1 and list2:
            if list1.val <= list2.val:
                current.next = list1
                list1 = list1.next
            else:
                current.next = list2
                list2 = list2.next
            # Move the current pointer forward
            current = current.next
            
        # At least one list is empty, attach the remaining elements.
        # Python evaluates to the first truthy value, making this a clean one-liner.
        current.next = list1 or list2
        
        # Return the actual head of the merged list
        return dummy.next
