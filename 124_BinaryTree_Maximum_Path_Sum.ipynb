# %% [markdown]
# ### 124. Binary Tree Maximum Path Sum
# #### A path in a binary tree is a sequence of nodes where each pair of adjacent nodes in the sequence has an edge connecting them. A node can only appear in the sequence at most once. Note that the path does not need to pass through the root.
# #### The path sum of a path is the sum of the node's values in the path.
# #### Given the root of a binary tree, return the maximum path sum of any non-empty path.

# %% [markdown]
# ###### ![image.png](attachment:image.png)

# %% [markdown]
# ### Description:
# ###### ![image.png](attachment:image.png)

# %% [markdown]
# ### Java Solution
# ```java
# class Solution {
#     private int maxSum;
#     public int maxPathSum(TreeNode root) {
#         maxSum = Integer.MIN_VALUE;
#         calculateMaxGain(root);
#         return maxSum;
#     }
#
#     private int calculateMaxGain(TreeNode node){
#         if(node==null){
#             return 0;
#         }
#
#         int leftGain = Math.max(0,calculateMaxGain(node.left));
#         int rightGain = Math.max(0,calculateMaxGain(node.right));
#         int currentSum = node.val+leftGain+rightGain;
#         maxSum = Math.max(maxSum,currentSum);
#         return node.val+Math.max(leftGain,rightGain);
#     }
# }
# ```

# %% [markdown]
# ### Cpp Solution
# ```cpp
# class Solution {
# public:
#     int maxPathSum(TreeNode* root) {
#         int maxSum = INT_MIN;
#         calculateMaxGain(root, maxSum);
#         return maxSum;
#     }
#
# private:
#     int calculateMaxGain(TreeNode* node, int& maxSum) {
#         if (!node) return 0;
#
#         // Ignore negative paths
#         int leftGain = max(0, calculateMaxGain(node->left, maxSum));
#         int rightGain = max(0, calculateMaxGain(node->right, maxSum));
#
#         // Sum if the current node is the peak
#         int currentPathSum = node->val + leftGain + rightGain;
#
#         // Update global max
#         maxSum = max(maxSum, currentPathSum);
#
#         // Return the max branch sum to parent
#         return node->val + max(leftGain, rightGain);
#     }
# };
# ```

# %% [markdown]
# ### Python Solution

# %%
class Solution:
    def maxPathSum(self, root: Optional[TreeNode]) -> int:
        max_sum = float('-inf')
        
        def calculate_max_gain(node):
            nonlocal max_sum
            
            if not node:
                return 0
            
            # Max gain from subtrees, floored at 0 to ignore negative paths
            left_gain = max(0, calculate_max_gain(node.left))
            right_gain = max(0, calculate_max_gain(node.right))
            
            # Path sum if this node is the peak
            current_path_sum = node.val + left_gain + right_gain
            
            # Update the global maximum
            max_sum = max(max_sum, current_path_sum)
            
            # Return max branch contribution to the parent
            return node.val + max(left_gain, right_gain)
            
        calculate_max_gain(root)
        return max_sum
